# %%
import codecs

# 전체 경로 지정
with open('C:/Hotel_Project/app.py', 'r', encoding='utf-8') as f:
    content = f.read()

# UTF-8로 저장
with open('C:/Hotel_Project/app_utf8.py', 'w', encoding='utf-8') as f:
    f.write(content)

print("✅ UTF-8 변환 완료!")
# Out:
# ✅ UTF-8 변환 완료!
